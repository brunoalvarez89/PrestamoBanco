# %%
from IPython.display import display
from IPython.display import HTML
import ipywidgets as widgets
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# funciones necesarias

# esta es la funcion de cuota mensual total
def get_cuota_mensual_total(p, i, n):
    num = p * i * (i+1)**n
    den = (i+1)**n - 1
    return num/den

# esta es la funcion de deuda capital en el mes t
def get_deuda_capital(p, i, n, t):
    coef = (((1+i)**t) - 1) / (((1+i)**n) - 1)
    return p * ( 1 - coef )

HTML('''<script>
  function code_toggle() {
    if (code_shown){
      $('div.input').hide('500');
      $('#toggleButton').val('Mostrar codigo')
    } else {
      $('div.input').show('500');
      $('#toggleButton').val('Ocultar codigo')
    }
    code_shown = !code_shown
  }
  $( document ).ready(function(){
    code_shown=false;
    $('div.input').hide()
  });
</script>
<form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Mostrar Codigo"></form>''')
# Out:
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Mostrar codigo')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Ocultar codigo')
#     }
#     code_shown = !code_shown
#   }
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Mostrar Codigo"></form>

# %% [markdown]
# ### Esta página calcula la cuota mensual que pagarías solicitando un crédito.
#
# Simplemente poné en los casilleros de abajo los datos solicitados, y al final vas a ver el listado de cuotas.
#
# ¿Cuánta plata (AR$) le pedís al banco?

# %%
p_w = widgets.BoundedFloatText(
    value=1000000,
    min=0,
    max=100000000,
    step=1,
    description='AR$',
    disabled=False
)
display(p_w)
# Out:
# BoundedFloatText(value=1000000.0, description='AR$', max=100000000.0, step=1.0)

# %% [markdown]
# ¿Cuál es el interés anual del crédito (en porcentaje)?

# %%
i_w = widgets.BoundedFloatText(
    value=20,
    min=0,
    max=100000000,
    step=0.1,
    description='Interes (%)',
    disabled=False
)
display(i_w)
# Out:
# BoundedFloatText(value=20.0, description='Interes (%)', max=100000000.0, step=0.1)

# %% [markdown]
# ¿De cuántos años es el crédito?

# %%
n_w = widgets.BoundedIntText(
    value=20,
    min=0,
    max=100,
    step=1,
    description='Anos',
    disabled=False
)
display(n_w)
# Out:
# BoundedIntText(value=20, description='Anos')

# %%
# extraigo valores de los textboxes
p = p_w.value
i = i_w.value / 12.0 * 0.01
n = n_w.value * 12

# calculo cuota mensual total
cuota_total = get_cuota_mensual_total(p, i, n)
print("Tu cuota mensual es de AR$ " + str(cuota_total) + "\n")

# muestro cuotas mensuales
cuota_capital = []
cuota_interes = []
deuda_capital = []

print("Este es tu listado de cuotas por mes: \n")
print("MES \t CAPITAL \t INTERESES \t CAPITAL ADEUDADO")

for t in range(1, n+1):    
 
    cuota_capital.append(get_deuda_capital(p, i, n, t-1) - get_deuda_capital(p, i, n, t))
    cuota_interes.append(cuota_total - cuota_capital[t-1])
    deuda_capital.append(get_deuda_capital(p, i, n, t))
    
    print(str(t) + "\t" + \
          str(cuota_capital[t-1]) + "\t" + \
          str(cuota_interes[t-1]) + "\t" + \
          str(deuda_capital[t-1])
         )
    
#print "\nY algunos graficos:"

#x = np.arange(1, n+1)
#plt.subplot(2, 1, 1)
#plt.scatter(x,np.asarray(deuda))
#plt.subplot(2, 1, 2)
#plt.scatter(x,np.asarray(cuota_interes))
#plt.scatter(x,np.asarray(cuota_capital))
#plt.show()
# Out:
# Tu cuota mensual es de AR$ 16988.246075597217
#
# Este es tu listado de cuotas por mes:
#
# MES 	 CAPITAL 	 INTERESES 	 CAPITAL ADEUDADO
# 1	321.5794089304982	16666.66666666672	999678.4205910695
# 2	326.9390657461481	16661.30700985107	999351.4815253234
# 3	332.3880501750391	16655.858025422178	999019.0934751483
# 4	337.92785101151094	16650.318224585706	998681.1656241368
# 5	343.559981861501	16644.686093735716	998337.6056422753
# 6	349.28598155942746	16638.96009403779	997988.3196607159
# 7	355.10741458518896	16633.138661012028	997633.2122461307
# 8	361.0258714950178	16627.2202041022	997272.1863746357
# 9	367.0429693532642	16621.203106243953	996905.1434052824
# 10	373.1603521758225	16615.085723421395	996531.9830531066
# 11	379.37969137879554	16608.86638421842	996152.6033617278
# 12	385.7026862350758	16602.54338936214	995766.9006754927
# 13	392.13106433907524	16596.11501125814	995374.7696111536
# 14	398.66658207797445	16589.579493519243	994976.1030290757
# 15	405.3110251126345	16582.935050484582	994570.792003963
# 16	412.0662088644458	16576.17986673277	994158.7257950986
# 17	418.9339790123049	16569.312096584912	993739.7918160863
# 18	425.91621199576184	16562.329863601455	993313.8756040905
# 19	433.0148155291099	16555.231260068107	992880.8607885614
# 20	440.23172912106384	16548.014346476153	992440.6290594403
# 21	447.5689246066613	16540.677150990556	991993.0601348337
# 22	455.02840668335557	16533.21766891386	991538.0317281503
# 23	462.6122134613106	16525.633862135906	991075.419514689
# 24	470.3224170190515	16517.923658578165	990605.09709767
# 25	478.1611239693593	16510.084951627858	990126.9359737006
# 26	486.13047603552695	16502.11559956169	989640.8054976651
# 27	494.23265063622966	16494.013424960987	989146.5728470288
# 28	502.46986148005817	16485.77621411716	988644.1029855488
# 29	510.84435917134397	16477.401716425873	988133.2586263774
# 30	519.3584318242501	16468.887643772967	987613.9001945532
# 31	528.0144056879217	16460.231669909295	987085.8857888653
# 32	536.8146457828116	16451.431429814405	986549.0711430825
# 33	545.7615565458545	16442.484519051362	986003.3095865366
# 34	554.8575824883301	16433.388493108887	985448.4520040483
# 35	564.1052088630386	16424.14086673418	984884.3467951852
# 36	573.5069623441668	16414.73911325305	984310.8398328411
# 37	583.0654117164668	16405.18066388075	983727.7744211246
# 38	592.7831685785204	16395.462907018697	983134.9912525461
# 39	602.662888054736	16385.58318754248	982532.3283644913
# 40	612.7072695223615	16375.538806074856	981919.621094969
# 41	622.9190573478118	16365.327018249405	981296.7020376212
# 42	633.3010416368488	16354.945033960368	980663.4009959843
# 43	643.8560589973349	16344.390016599882	980019.544936987
# 44	654.586993314093	16333.659082283124	979364.9579436729
# 45	665.4967765361071	16322.74929906111	978699.4611671368
# 46	676.5883894782746	16311.657686118942	978022.8727776585
# 47	687.8648626363138	16300.381212960903	977335.0079150222
# 48	699.3292770134285	16288.916798583788	976635.6786380088
# 49	710.9847649637377	16277.26131063348	975924.693873045
# 50	722.8345110464143	16265.411564550803	975201.8593619986
# 51	734.8817528971704	16253.364322700047	974466.9776091015
# 52	747.1297821123153	16241.116293484902	973719.8478269891
# 53	759.5819451473653	16228.664130449852	972960.2658818418
# 54	772.241644233116	16216.004431364101	972188.0242376087
# 55	785.1123383038212	16203.133737293396	971402.9118993048
# 56	798.1975439420203	16190.048531655197	970604.7143553628
# 57	811.5008363411762	16176.74523925604	969793.2135190216
# 58	825.0258502803044	16163.220225316913	968968.1876687413
# 59	838.7762811181601	16149.469794479057	968129.4113876232
# 60	852.75588580349	16135.490189793727	967276.6555018197
# 61	866.9684839001857	16121.277591697031	966409.6870179195
# 62	881.4179586318787	16106.828116965338	965528.2690592876
# 63	896.1082579424838	16092.137817654733	964632.1608013451
# 64	911.0433955747867	16077.20268002243	963721.1174057703
# 65	926.2274521677755	16062.018623429442	962794.8899536026
# 66	941.6645763703855	16046.581499226832	961853.2253772322
# 67	957.3589859767817	16030.887089620435	960895.8663912554
# 68	973.3149690761929	16014.931106521024	959922.5514221792
# 69	989.5368852275424	15998.709190369675	958933.0145369517
# 70	1006.029166648048	15982.216908949169	957926.9853703036
# 71	1022.7963194254553	15965.449756171762	956904.1890508782
# 72	1039.8429247492459	15948.403150847971	955864.3461261289
# 73	1057.1736401617527	15931.072435435464	954807.1724859672
# 74	1074.7932008310454	15913.452874766172	953732.3792851361
# 75	1092.7064208448865	15895.53965475233	952639.6728642912
# 76	1110.9181945257587	15877.327881071458	951528.7546697655
# 77	1129.433497767779	15858.812577829438	950399.3211719977
# 78	1148.2573893973604	15839.988686199857	949251.0637826003
# 79	1167.3950125537813	15820.851063043436	948083.6687700466
# 80	1186.8515960964141	15801.394479500803	946896.8171739501
# 81	1206.6324560313951	15781.613619565822	945690.1847179187
# 82	1226.7429969651857	15761.503078632031	944463.4417209536
# 83	1247.1887135813013	15741.057362015916	943216.2530073723
# 84	1267.975192141137	15720.27088345608	941948.2778152311
# 85	1289.1081120099407	15699.137963587276	940659.1697032212
# 86	1310.5932472101413	15677.652828387076	939348.576456011
# 87	1332.4364679971477	15655.80960760007	938016.1399880139
# 88	1354.6437424635515	15633.602333133666	936661.4962455503
# 89	1377.2211381715024	15611.024937425715	935284.2751073788
# 90	1400.174823807436	15588.071251789781	933884.1002835714
# 91	1423.5110708710272	15564.73500472619	932460.5892127004
# 92	1447.2362553855637	15541.009820211653	931013.3529573148
# 93	1471.3568596419645	15516.889215955252	929541.9960976728
# 94	1495.8794739693403	15492.366601627877	928046.1166237035
# 95	1520.8107985354727	15467.435277061744	926525.305825168
# 96	1546.1576451777946	15442.088430419422	924979.1481799902
# 97	1571.9269392639399	15416.319136333277	923407.2212407263
# 98	1598.125721585122	15390.120354012095	921809.0955191412
# 99	1624.7611502782675	15363.48492531895	920184.3343688629
# 100	1651.8405027827248	15336.405572814492	918532.4938660802
# 101	1679.37117782922	15308.874897767997	916853.122688251
# 102	1707.3606974597787	15280.885378137438	915145.7619907912
# 103	1735.8167090839706	15252.429366513246	913409.9452817072
# 104	1764.7469875686802	15223.499088028537	911645.1982941385
# 105	1794.159437361639	15194.086638235578	909851.0388567769
# 106	1824.0620946509298	15164.183980946287	908026.976762126
# 107	1854.4631295618601	15133.782946035357	906172.5136325641
# 108	1885.370848387829	15102.875227209388	904287.1427841763
# 109	1916.7936958608916	15071.452379736325	902370.3490883154
# 110	1948.740257458645	15039.505818138572	900421.6088308567
# 111	1981.2192617495311	15007.026813847686	898440.3895691072
# 112	2014.2395827787695	14974.006492818447	896426.1499863284
# 113	2047.8102424916578	14940.43583310556	894378.3397438368
# 114	2081.9404132000636	14906.305662397153	892296.3993306367
# 115	2116.639420086518	14871.606655510699	890179.7599105502
# 116	2151.916743754642	14836.329331842575	888027.8431667956
# 117	2187.7820228174096	14800.464052779807	885840.0611439781
# 118	2224.2450565309264	14764.00101906629	883615.8160874472
# 119	2261.315807473031	14726.930268124186	881354.5002799742
# 120	2299.004404264386	14689.241671332831	879055.4958757098
# 121	2337.321144335321	14650.924931261896	876718.1747313745
# 122	2376.276496740873	14611.969578856344	874341.8982346336
# 123	2415.88110502006	14572.364970577157	871926.0171296136
# 124	2456.14579010359	14532.100285493627	869469.87133951
# 125	2497.081553272088	14491.164522325129	866972.7897862379
# 126	2538.699579159962	14449.546496437255	864434.0902070779
# 127	2581.011238812469	14407.234836784748	861853.0789682654
# 128	2624.0280927928397	14364.217982804377	859229.0508754726
# 129	2667.7618943393463	14320.48418125787	856561.2889811333
# 130	2712.224592578248	14276.021483018969	853849.064388555
# 131	2757.4283357880777	14230.81773980914	851091.6360527669
# 132	2803.38547471771	14184.860600879507	848288.2505780492
# 133	2850.10856596299	14138.137509634227	845438.1420120862
# 134	2897.6103753958596	14090.635700201357	842540.5316366904
# 135	2945.9038816522807	14042.342193944936	839594.6277550381
# 136	2995.0022796799894	13993.243795917228	836599.6254753581
# 137	3044.9189843412023	13943.327091256015	833554.7064910169
# 138	3095.6676340802805	13892.578441516936	830459.0388569366
# 139	3147.2620946482057	13840.983980949011	827311.7767622884
# 140	3199.71646289248	13788.529612704737	824112.0602993959
# 141	3253.045070607215	13735.201004990002	820859.0152287887
# 142	3307.2624884507386	13680.983587146478	817551.752740338
# 143	3362.3835299247876	13625.86254567243	814189.3692104132
# 144	3418.4232554237824	13569.822820173435	810770.9459549894
# 145	3475.396976347314	13512.849099249903	807295.5489786421
# 146	3533.3202592865564	13454.92581631066	803762.2287193555
# 147	3592.208930274588	13396.037145322629	800170.019789081
# 148	3652.0790791123873	13336.16699648483	796517.9407099686
# 149	3712.9470637645572	13275.29901183266	792804.993646204
# 150	3774.8295148271136	13213.416560770103	789030.1641313769
# 151	3837.743340074201	13150.502735523016	785192.4207913027
# 152	3901.705729075591	13086.540346521626	781290.7150622271
# 153	3966.734157893341	13021.511917703876	777323.9809043338
# 154	4032.8463938583154	12955.399681738902	773291.1345104754
# 155	4100.060500422609	12888.185575174608	769191.0740100528
# 156	4168.394842096372	12819.851233500845	765022.6791679565
# 157	4237.868089464493	12750.377986132724	760784.811078492
# 158	4308.499224288971	12679.746851308246	756476.311854203
# 159	4380.307544693933	12607.938530903284	752096.0043095091
# 160	4453.312670438667	12534.93340515855	747642.6916390704
# 161	4527.534548279364	12460.711527317853	743115.157090791
# 162	4602.993457417353	12385.252618179864	738512.1636333737
# 163	4679.710015040939	12308.536060556278	733832.4536183327
# 164	4757.70518195827	12230.540893638947	729074.7484363745
# 165	4837.000268324395	12151.245807272822	724237.7481680501
# 166	4917.616939462954	12070.629136134263	719320.1312285871
# 167	4999.577221787535	11988.668853809682	714320.5540067996
# 168	5082.903508817079	11905.342566780138	709237.6504979825
# 169	5167.618567297584	11820.627508299633	704070.0319306849
# 170	5253.745543419034	11734.500532178183	698816.2863872659
# 171	5341.307969142799	11646.938106454418	693474.9784181231
# 172	5430.329768628464	11557.916306968753	688044.6486494946
# 173	5520.835264772293	11467.410810824924	682523.8133847223
# 174	5612.849185851752	11375.396889745465	676910.9641988706
# 175	5706.396672282717	11281.8494033145	671204.5675265879
# 176	5801.5032834874	11186.742792109817	665403.0642431005
# 177	5898.195004879031	11090.051070718186	659504.8692382214
# 178	5996.498254960054	10991.747820637163	653508.3709832614
# 179	6096.439892542781	10891.806183054436	647411.9310907186
# 180	6198.047224085312	10790.198851511905	641213.8838666333
# 181	6301.3480111532845	10686.898064443933	634912.53585548
# 182	6406.370478005847	10581.87559759137	628506.1653774742
# 183	6513.143319305964	10475.102756291253	621993.0220581682
# 184	6621.695707960986	10366.550367636231	615371.3263502072
# 185	6732.057303093839	10256.188772503378	608639.2690471134
# 186	6844.25825814507	10143.987817452147	601795.0107889683
# 187	6958.329229114461	10029.916846482756	594836.6815598538
# 188	7074.301382933045	9913.944692664172	587762.3801769208
# 189	7192.206405981793	9796.039669615424	580570.173770939
# 190	7312.0765127483755	9676.169562848841	573258.0972581906
# 191	7433.944454627112	9554.301620970105	565824.1528035635
# 192	7557.843528871308	9430.402546725909	558266.3092746922
# 193	7683.807587685529	9304.438487911688	550582.5016870067
# 194	7811.871047480381	9176.375028116836	542770.6306395263
# 195	7942.068898271769	9046.177177325448	534828.5617412545
# 196	8074.436713243136	8913.80936235408	526754.1250280114
# 197	8209.010658463521	8779.235417133696	518545.11436954787
# 198	8345.827502771455	8642.418572825762	510199.2868667764
# 199	8484.924627817585	8503.321447779632	501714.3622389588
# 200	8626.340038281109	8361.906037316108	493088.0222006777
# 201	8770.112372252566	8218.13370334465	484317.90982842515
# 202	8916.28091179009	8071.965163807126	475401.62891663506
# 203	9064.885593653366	7923.3604819438515	466336.7433229817
# 204	9215.967020214128	7772.279055383089	457120.77630276757
# 205	9369.566470551072	7618.679605046145	447751.2098322165
# 206	9525.725911726826	7462.520163870391	438225.48392048967
# 207	9684.488010255678	7303.758065341539	428540.995910234
# 208	9845.896143760008	7142.349931837209	418695.099766474
# 209	10009.994412822532	6978.2516627746845	408685.10535365145
# 210	10176.827653036336	6811.418422560881	398508.2777006151
# 211	10346.441447253572	6641.804628343645	388161.83625336154
# 212	10518.882138041314	6469.363937555903	377642.95411532023
# 213	10694.196840341669	6294.049235255548	366948.75727497856
# 214	10872.433454347658	6115.812621249559	356076.3238206309
# 215	11053.640678586613	5934.605397010604	345022.6831420443
# 216	11237.868023229763	5750.378052367454	333784.8151188145
# 217	11425.16582361696	5563.080251980256	322359.64929519757
# 218	11615.585254010512	5372.660821586705	310744.06404118706
# 219	11809.17834157747	5179.067734019747	298934.8856996096
# 220	12005.99798060354	4982.248094993676	286928.88771900604
# 221	12206.09794694715	4782.1481286500675	274722.7897720589
# 222	12409.53291272954	4578.713162867676	262313.25685932935
# 223	12616.358461275056	4371.8876143221605	249696.8983980543
# 224	12826.631102296204	4161.614973301013	236870.2672957581
# 225	13040.408287334547	3947.83778826267	223829.85900842355
# 226	13257.748425456783	3730.4976501404344	210572.11058296676
# 227	13478.710899214493	3509.535176382724	197093.39968375227
# 228	13703.356080867816	3284.889994729401	183390.04360288446
# 229	13931.745348882512	3056.500726714705	169458.29825400194
# 230	14163.941104697093	2824.3049709001243	155294.35714930485
# 231	14400.00678977539	2588.2392858218263	140894.35035952946
# 232	14640.006902938432	2348.239172658785	126254.34345659103
# 233	14884.007017987198	2104.239057610019	111370.33643860383
# 234	15132.073801620514	1856.1722739767029	96238.26263698332
# 235	15384.275031647296	1603.9710439499213	80853.98760533602
# 236	15640.6796155083	1347.5664600889177	65213.30798982772
# 237	15901.357609100058	1086.8884664971592	49311.95038072766
# 238	16166.380235918426	821.8658396787905	33145.57014480924
# 239	16435.819906516885	552.4261690803323	16709.750238292352
# 240	16709.750238292352	278.49583730486484	0.0
